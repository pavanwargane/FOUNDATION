# %% [markdown]
# ### ITERATORS

# %%
my_list=[1,2,3,4,5,6]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
 ## iterator
iterator=iter(my_list)
print(iterator)

# %%
##3 iterate through all element

next(iterator)
# Out:
# 2

# %%
iterator=iter(my_list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("there are no elements in the iterator")
# Out:
# there are no elements in the iterator
